# %%
from PIL import Image
from PIL.TiffTags import TAGS
import struct
import json

# %%
with Image.open('/Users/akre96/Data/BE_224B/Density Research Lab 18 samples/D3 R6 day 9/Image1_dots.tif') as img:
    meta_dict = {TAGS[key] : img.tag[key] for key in img.tag.keys()}

# %%
meta_dict
# Out:
# {'ImageWidth': (200,),
#  'ImageLength': (200,),
#  'BitsPerSample': (8, 8, 8),
#  'PhotometricInterpretation': (2,),
#  'ResolutionUnit': (1,),
# ...

# %%
vals = list(bytearray(meta_dict['ImageJMetaData'][20:]))
len(vals)
# Out:
# 1356
